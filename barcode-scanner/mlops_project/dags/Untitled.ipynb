# %%
import os
print("Текущая директория:", os.getcwd())
print("\nСодержимое work/:")
# !ls -la /home/jovyan/work/
print("\nСодержимое scripts/:")
# !ls -la /home/jovyan/work/scripts/
# Out:
# Текущая директория: /home/jovyan/work/dags
#
# Содержимое work/:
# total 32
# drwsrwsr-x 1 jovyan users 4096 Mar  6 14:24 .
# drwsrws--- 1 jovyan users 4096 Mar  6 14:24 ..
# drwxr-xr-x 3 jovyan   999 4096 Mar  6 14:28 dags
# drwxr-xr-x 4 jovyan   999 4096 Mar  6 13:55 data
# drwxr-xr-x 2 root   root  4096 Mar  6 14:24 .env
# drwxr-xr-x 2 jovyan   999 4096 Mar  5 08:01 notebooks
# drwxr-xr-x 2 jovyan   999 4096 Mar  5 08:01 scripts
#
# Содержимое scripts/:
# total 8
# drwxr-xr-x 2 jovyan   999 4096 Mar  5 08:01 .
# drwsrwsr-x 1 jovyan users 4096 Mar  6 14:24 ..
