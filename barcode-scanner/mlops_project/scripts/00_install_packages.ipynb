# %%
# !pip install pandas numpy matplotlib seaborn scikit-learn pyodbc sqlalchemy psycopg2-binary python-dotenv boto3 botocore

# Ячейка 2 - проверка
import sys
print(f"Python version: {sys.version}")
import pandas as pd
print(f"Pandas version: {pd.__version__}")
print("✅ Готово!")
# Out:
# ...
# Python version: 3.11.6 | packaged by conda-forge | (main, Oct  3 2023, 10:40:35) [GCC 12.3.0]
# Pandas version: 2.1.1
# ✅ Готово!

# %%
# !pip install -i https://pypi.tuna.tsinghua.edu.cn/simple minio
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.8/93.8 kB 834.4 kB/s eta 0:00:000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 725.6 kB/s eta 0:00:0000:0100:01
# ...

# %%
# !pip install -i https://pypi.tuna.tsinghua.edu.cn/simple pymssql
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 583.3 kB/s eta 0:00:0000:0100:01
# ...

# %%
# !pip install -i https://pypi.tuna.tsinghua.edu.cn/simple pyodbc
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...

# %%
# !pip install xgboost
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.7/131.7 MB 827.6 kB/s eta 0:00:000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.6/293.6 MB 706.6 kB/s eta 0:00:000:0100:02��━━━╸ 293.6/293.6 MB 5.6 MB/s eta 0:00:01
# ...

# %%
# !pip install -i https://pypi.tuna.tsinghua.edu.cn/simple clickhouse-driver
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 998.3/998.3 kB 756.1 kB/s eta 0:00:0000:0100:01
# ...

# %%
# !pip install pytrends
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 2.4 MB/s eta 0:00:0000:0100:01
# ...

# %%
# !pip install papermill
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/papermill/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/papermill/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/papermill/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/papermill/
# ^C
# ...

# %%
# !pip install -i https://pypi.tuna.tsinghua.edu.cn/simple papermill
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.9/88.9 kB 172.5 kB/s eta 0:00:00a 0:00:01
# ...
